# %% [markdown]
# # Jeu du taquin

# %%
from code.Agents.RandomAgent import RandomAgent
from code.Agent import Agent
from code.Game import Game
from code.Agents.QlearningAgent import QLearningAgent
from code.Agents.SarsaAgent import SarsaAgent

# %%
game=Game()

# %%
game.play_game(agent=RandomAgent(),
               stop=1000,
               print_game=True,
               train=True)
# Out:
# ply
# ---- 1 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 99
# ---- 2 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 198
# ---- 3 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 187
# ---- 4 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 176
# ---- 5 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 165
# ---- 6 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 154
# ---- 7 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 143
# ---- 8 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 132
# ---- 9 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 121
# ---- 10 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 110
# ---- 11 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 99
# ---- 12 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 88
# ---- 13 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 77
# ---- 14 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 66
# ---- 15 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 55
# ---- 16 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 44
# ---- 17 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 33
# ---- 18 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 22
# ---- 19 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 11
# ---- 20 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 0
# ---- 21 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -11
# ---- 22 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -22
# ---- 23 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -33
# ---- 24 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -44
# ---- 25 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -55
# ---- 26 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -66
# ---- 27 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -77
# ---- 28 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -88
# ---- 29 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -99
# ---- 30 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -110
# ---- 31 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -121
# ---- 32 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -132
# ---- 33 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -143
# ---- 34 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -154
# ---- 35 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -165
# ---- 36 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -176
# ---- 37 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -187
# ---- 38 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -198
# ---- 39 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -209
# ---- 40 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -220
# ---- 41 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -231
# ---- 42 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -242
# ---- 43 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -253
# ---- 44 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -264
# ---- 45 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -275
# ---- 46 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -286
# ---- 47 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -297
# ---- 48 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -308
# ---- 49 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -319
# ---- 50 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -330
# ---- 51 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -341
# ---- 52 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -352
# ---- 53 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -363
# ---- 54 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -374
# ---- 55 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -385
# ---- 56 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -396
# ---- 57 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -407
# ---- 58 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -418
# ---- 59 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -429
# ---- 60 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -440
# ---- 61 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -451
# ---- 62 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -462
# ---- 63 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -473
# ---- 64 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -484
# ---- 65 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -495
# ---- 66 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -506
# ---- 67 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -517
# ---- 68 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -528
# ---- 69 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -539
# ---- 70 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -550
# ---- 71 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -561
# ---- 72 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -572
# ---- 73 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -583
# ---- 74 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -594
# ---- 75 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -605
# ---- 76 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -616
# ---- 77 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -627
# ---- 78 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -638
# ---- 79 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -649
# ---- 80 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -660
# ---- 81 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -671
# ---- 82 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -682
# ---- 83 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -693
# ---- 84 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -704
# ---- 85 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -715
# ---- 86 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -726
# ---- 87 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -737
# ---- 88 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -748
# ---- 89 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -759
# ---- 90 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -770
# ---- 91 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -781
# ---- 92 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -792
# ---- 93 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -803
# ---- 94 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -814
# ---- 95 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -825
# ---- 96 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -836
# ---- 97 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -847
# ---- 98 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -858
# ---- 99 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -869
# ---- 100 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -880
# ---- 101 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -891
# ---- 102 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -902
# ---- 103 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -913
# ---- 104 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -924
# ---- 105 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -935
# ---- 106 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -946
# ---- 107 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -957
# ---- 108 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -968
# ---- 109 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -979
# ---- 110 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -990
# ---- 111 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1001
# ---- 112 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1012
# ---- 113 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1023
# ---- 114 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1034
# ---- 115 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1045
# ---- 116 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1056
# ---- 117 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1067
# ---- 118 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1078
# ---- 119 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1089
# ---- 120 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -
----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10120
# ---- 941 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10131
# ---- 942 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10142
# ---- 943 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10153
# ---- 944 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10164
# ---- 945 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10175
# ---- 946 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10186
# ---- 947 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10197
# ---- 948 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10208
# ---- 949 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10219
# ---- 950 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10230
# ---- 951 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10241
# ---- 952 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10252
# ---- 953 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10263
# ---- 954 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10274
# ---- 955 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10285
# ---- 956 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10296
# ---- 957 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10307
# ---- 958 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10318
# ---- 959 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10329
# ---- 960 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10340
# ---- 961 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10351
# ---- 962 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10362
# ---- 963 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10373
# ---- 964 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10384
# ---- 965 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10395
# ---- 966 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10406
# ---- 967 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10417
# ---- 968 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10428
# ---- 969 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10439
# ---- 970 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10450
# ---- 971 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10461
# ---- 972 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10472
# ---- 973 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10483
# ---- 974 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10494
# ---- 975 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10505
# ---- 976 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10516
# ---- 977 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10527
# ---- 978 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10538
# ---- 979 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10549
# ---- 980 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10560
# ---- 981 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10571
# ---- 982 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10582
# ---- 983 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10593
# ---- 984 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10604
# ---- 985 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10615
# ---- 986 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10626
# ---- 987 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10637
# ---- 988 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10648
# ---- 989 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10659
# ---- 990 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10670
# ---- 991 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10681
# ---- 992 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10692
# ---- 993 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10703
# ---- 994 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10714
# ---- 995 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10725
# ---- 996 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10736
# ---- 997 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10747
# ---- 998 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10758
# ---- 999 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10769
# ---- 1000 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10780
# True

# %%
qlearner=QLearningAgent(size=game.grid.size)
Game().play_game(agent=qlearner,
               stop=1000,
               print_game=True,
               train=True)
# Out:
# ply
# ---- 1 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -11
# ---- 2 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 88
# ---- 3 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 77
# ---- 4 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 66
# ---- 5 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 55
# ---- 6 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 44
# ---- 7 ----------
#
# ┌────┬────┐
# │  1 │  2 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 143
# ---- 8 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  1 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 132
# ---- 9 ----------
#
# ┌────┬────┐
# │  1 │  2 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 121
# ---- 10 ----------
#
# ┌────┬────┐
# │  1 │  2 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 50120
# True

# %%
qlearner.played_round
# Out:
# 10

# %%
sarsaearner=SarsaAgent(size=game.grid.size)
Game().play_game(agent=sarsaearner,
               stop=1000,
               print_game=True,
               train=True)
# Out:
# ply
# ---- 1 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -11
# ---- 2 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 88
# ---- 3 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 77
# ---- 4 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 66
# ---- 5 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 55
# ---- 6 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 44
# ---- 7 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 33
# ---- 8 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 22
# ---- 9 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 11
# ---- 10 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 0
# ---- 11 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -11
# ---- 12 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -22
# ---- 13 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -33
# ---- 14 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -44
# ---- 15 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -55
# ---- 16 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -66
# ---- 17 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -77
# ---- 18 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -88
# ---- 19 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -99
# ---- 20 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -110
# ---- 21 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -121
# ---- 22 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -132
# ---- 23 ----------
#
# ┌────┬────┐
# │  2 │  3 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -143
# ---- 24 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -154
# ---- 25 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -165
# ---- 26 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -176
# ---- 27 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  2 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -187
# ---- 28 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -198
# ---- 29 ----------
#
# ┌────┬────┐
# │  3 │  1 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -209
# ---- 30 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  3 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -220
# ---- 31 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  3 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -121
# ---- 32 ----------
#
# ┌────┬────┐
# │  1 │  2 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 49878
# True

# %%
from code.Agents.MonteCarloAgent import MonteCarloAgent


mcLearner=MonteCarloAgent(size=game.grid.size)

# %%
Game().play_game(agent=mcLearner,
               stop=1000,
               print_game=True,
               train=True)
# Out:
# ply
# ---- 1 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -11
# ---- 2 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -22
# ---- 3 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -23
# ---- 4 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 76
# ---- 5 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 175
# ---- 6 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 164
# ---- 7 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 153
# ---- 8 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 142
# ---- 9 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 131
# ---- 10 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 120
# ---- 11 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 109
# ---- 12 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: 98
# ---- 13 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 87
# ---- 14 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 76
# ---- 15 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: 65
# ---- 16 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 54
# ---- 17 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 43
# ---- 18 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 32
# ---- 19 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: 21
# ---- 20 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: 10
# ---- 21 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1
# ---- 22 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -12
# ---- 23 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -23
# ---- 24 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -34
# ---- 25 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -45
# ---- 26 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -56
# ---- 27 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -67
# ---- 28 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -78
# ---- 29 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -89
# ---- 30 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -100
# ---- 31 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -111
# ---- 32 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -122
# ---- 33 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -133
# ---- 34 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -144
# ---- 35 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -155
# ---- 36 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -166
# ---- 37 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -177
# ---- 38 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -188
# ---- 39 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -199
# ---- 40 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -210
# ---- 41 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -221
# ---- 42 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -232
# ---- 43 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -243
# ---- 44 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -254
# ---- 45 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -265
# ---- 46 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -276
# ---- 47 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -287
# ---- 48 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -298
# ---- 49 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -309
# ---- 50 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -320
# ---- 51 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -331
# ---- 52 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -342
# ---- 53 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -353
# ---- 54 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -364
# ---- 55 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -375
# ---- 56 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -386
# ---- 57 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -397
# ---- 58 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -408
# ---- 59 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -419
# ---- 60 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -430
# ---- 61 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -441
# ---- 62 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -452
# ---- 63 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -463
# ---- 64 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -474
# ---- 65 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -485
# ---- 66 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -496
# ---- 67 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -507
# ---- 68 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -518
# ---- 69 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -529
# ---- 70 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -540
# ---- 71 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │  2 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -551
# ---- 72 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -562
# ---- 73 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -573
# ---- 74 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -584
# ---- 75 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -595
# ---- 76 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -606
# ---- 77 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -617
# ---- 78 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -628
# ---- 79 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -639
# ---- 80 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -650
# ---- 81 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -661
# ---- 82 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -672
# ---- 83 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -683
# ---- 84 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -694
# ---- 85 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -705
# ---- 86 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -716
# ---- 87 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -727
# ---- 88 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -738
# ---- 89 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -749
# ---- 90 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -760
# ---- 91 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -771
# ---- 92 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -782
# ---- 93 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -793
# ---- 94 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -804
# ---- 95 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -815
# ---- 96 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -826
# ---- 97 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -837
# ---- 98 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -848
# ---- 99 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -859
# ---- 100 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -870
# ---- 101 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -881
# ---- 102 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -892
# ---- 103 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -903
# ---- 104 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -914
# ---- 105 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -925
# ---- 106 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -936
# ---- 107 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -947
# ---- 108 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -958
# ---- 109 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -969
# ---- 110 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -980
# ---- 111 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -991
# ---- 112 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1002
# ---- 113 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1013
# ---- 114 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1024
# ---- 115 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1035
# ---- 116 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1046
# ---- 117 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1057
# ---- 118 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1068
# ---- 119 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1079
# ---- 120 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1090
# ---- 121 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1101
# ---- 122 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -1112
# ---- 123 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1123
# ---- 124 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1134
# ---- 125 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1145
# ---- 126 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -
----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10187
# ---- 948 ----------
#
# ┌────┬────┐
# │  1 │    │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10198
# ---- 949 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10209
# ---- 950 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10220
# ---- 951 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10231
# ---- 952 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10242
# ---- 953 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10253
# ---- 954 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10264
# ---- 955 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10275
# ---- 956 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10286
# ---- 957 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10297
# ---- 958 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10308
# ---- 959 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10319
# ---- 960 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10330
# ---- 961 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10341
# ---- 962 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10352
# ---- 963 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10363
# ---- 964 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10374
# ---- 965 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10385
# ---- 966 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10396
# ---- 967 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10407
# ---- 968 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10418
# ---- 969 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10429
# ---- 970 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10440
# ---- 971 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10451
# ---- 972 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10462
# ---- 973 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10473
# ---- 974 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10484
# ---- 975 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10495
# ---- 976 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10506
# ---- 977 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10517
# ---- 978 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10528
# ---- 979 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10539
# ---- 980 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10550
# ---- 981 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10561
# ---- 982 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10572
# ---- 983 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10583
# ---- 984 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10594
# ---- 985 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10605
# ---- 986 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10616
# ---- 987 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10627
# ---- 988 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10638
# ---- 989 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10649
# ---- 990 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10660
# ---- 991 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10671
# ---- 992 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10682
# ---- 993 ----------
#
# ┌────┬────┐
# │    │  2 │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10693
# ---- 994 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10704
# ---- 995 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10715
# ---- 996 ----------
#
# ┌────┬────┐
# │  2 │    │
# ├────┼────┤
# │  3 │  1 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10726
# ---- 997 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │  3 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10737
# ---- 998 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10748
# ---- 999 ----------
#
# ┌────┬────┐
# │    │  1 │
# ├────┼────┤
# │  2 │  3 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10759
# ---- 1000 ----------
#
# ┌────┬────┐
# │  2 │  1 │
# ├────┼────┤
# │    │  3 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -10770
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# True

# %%
print("N  dict at the end of the first game")
print(mcLearner.N)
print("Q dict at the end of the first game")
print(mcLearner.Q)
print(f"Number of round played: {mcLearner.played_round}")
# Out:
# N  dict at the end of the first game
# {((1, 0, 2, 3), 1): 1, ((0, 1, 2, 3), 2): 1, ((2, 1, 0, 3), 3): 1, ((2, 1, 3, 0), 0): 1, ((2, 0, 3, 1), 1): 1, ((0, 2, 3, 1), 2): 1, ((3, 2, 0, 1), 3): 1, ((3, 2, 1, 0), 0): 1, ((3, 0, 1, 2), 1): 1, ((0, 3, 1, 2), 3): 1, ((1, 3, 0, 2), 0): 1, ((1, 3, 2, 0), 1): 1}
# Q dict at the end of the first game
# {((1, 0, 2, 3), 1): 15.222668686420702, ((0, 1, 2, 3), 2): 15.802965207134115, ((2, 1, 0, 3), 3): 15.336628007926778, ((2, 1, 3, 0), 0): 13.707364453251996, ((2, 0, 3, 1), 1): 15.230404948057759, ((0, 2, 3, 1), 2): 15.811561053397512, ((3, 2, 0, 1), 3): 15.34617894821945, ((3, 2, 1, 0), 0): 13.71797660913272, ((3, 0, 1, 2), 1): 15.242196232369695, ((0, 3, 1, 2), 3): 15.82466248041078, ((1, 3, 0, 2), 0): 15.213572592949543, ((1, 3, 2, 0), 1): 15.066629071261355}
# Number of round played: 1000

# %%
Game().play_game(agent=mcLearner,
               stop=1000,
               print_game=True,
               train=True)
# Out:
# ply
# ---- 1 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -11
# ---- 2 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -22
# ---- 3 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -33
# ---- 4 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -44
# ---- 5 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -55
# ---- 6 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -66
# ---- 7 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -77
# ---- 8 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -88
# ---- 9 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -99
# ---- 10 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -110
# ---- 11 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -121
# ---- 12 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -132
# ---- 13 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -143
# ---- 14 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -154
# ---- 15 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -165
# ---- 16 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -176
# ---- 17 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -187
# ---- 18 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -198
# ---- 19 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -209
# ---- 20 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -220
# ---- 21 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -221
# ---- 22 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -232
# ---- 23 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -243
# ---- 24 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -254
# ---- 25 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -265
# ---- 26 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -276
# ---- 27 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -287
# ---- 28 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -298
# ---- 29 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -309
# ---- 30 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -320
# ---- 31 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -331
# ---- 32 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -342
# ---- 33 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -353
# ---- 34 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -364
# ---- 35 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -375
# ---- 36 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -386
# ---- 37 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -397
# ---- 38 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -408
# ---- 39 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -419
# ---- 40 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -430
# ---- 41 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -441
# ---- 42 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -452
# ---- 43 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -463
# ---- 44 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -474
# ---- 45 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -475
# ---- 46 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -486
# ---- 47 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -497
# ---- 48 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -508
# ---- 49 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -519
# ---- 50 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -530
# ---- 51 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -541
# ---- 52 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -552
# ---- 53 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -563
# ---- 54 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -574
# ---- 55 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -585
# ---- 56 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -596
# ---- 57 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -607
# ---- 58 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -618
# ---- 59 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -629
# ---- 60 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -640
# ---- 61 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -651
# ---- 62 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -662
# ---- 63 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -673
# ---- 64 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -684
# ---- 65 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -685
# ---- 66 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -696
# ---- 67 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -707
# ---- 68 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -718
# ---- 69 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -729
# ---- 70 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -740
# ---- 71 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -751
# ---- 72 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -762
# ---- 73 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -773
# ---- 74 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -784
# ---- 75 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -795
# ---- 76 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -806
# ---- 77 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -817
# ---- 78 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -828
# ---- 79 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -839
# ---- 80 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -850
# ---- 81 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -861
# ---- 82 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -872
# ---- 83 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -883
# ---- 84 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -894
# ---- 85 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -905
# ---- 86 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -916
# ---- 87 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -917
# ---- 88 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -928
# ---- 89 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -929
# ---- 90 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -940
# ---- 91 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -951
# ---- 92 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -962
# ---- 93 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -973
# ---- 94 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -984
# ---- 95 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -995
# ---- 96 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1006
# ---- 97 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1017
# ---- 98 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1028
# ---- 99 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1039
# ---- 100 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1050
# ---- 101 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1061
# ---- 102 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1072
# ---- 103 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1083
# ---- 104 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1094
# ---- 105 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1105
# ---- 106 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1116
# ---- 107 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1127
# ---- 108 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1138
# ---- 109 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1149
# ---- 110 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1160
# ---- 111 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1161
# ---- 112 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1172
# ---- 113 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -1173
# ---- 114 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1184
# ---- 115 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1195
# ---- 116 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1206
# ---- 117 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1217
# ---- 118 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1228
# ---- 119 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1239
# ---- 120 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1250
# ---- 121 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1261
# ---- 122 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1272
# ---- 123 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1283
# ---- 124 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1294
# ---- 125 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1305
# ---- 126 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1316
# ---- 127 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1327
# ---- 128 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1338
# ---- 129 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1349
# ---- 130 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1360
# ---- 131 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1371
# ---- 132 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1382
# ---- 133 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1393
# ---- 134 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1404
# ---- 135 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -1415
# ---- 136 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -1426
# ---- 137 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -
----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2713
# ---- 274 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2724
# ---- 275 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2735
# ---- 276 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2746
# ---- 277 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2757
# ---- 278 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2768
# ---- 279 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -2779
# ---- 280 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -2790
# ---- 281 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -2801
# ---- 282 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2812
# ---- 283 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2823
# ---- 284 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2834
# ---- 285 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2845
# ---- 286 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2856
# ---- 287 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2867
# ---- 288 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2878
# ---- 289 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -2889
# ---- 290 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │    │  1 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -2900
# ---- 291 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -2911
# ---- 292 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2922
# ---- 293 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2933
# ---- 294 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2944
# ---- 295 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2955
# ---- 296 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2966
# ---- 297 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2977
# ---- 298 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -2988
# ---- 299 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -2999
# ---- 300 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -3010
# ---- 301 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3021
# ---- 302 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -3032
# ---- 303 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3043
# ---- 304 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3054
# ---- 305 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3065
# ---- 306 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3076
# ---- 307 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3087
# ---- 308 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3098
# ---- 309 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3109
# ---- 310 ----------
#
# ┌────┬────┐
# │  1 │  3 │
# ├────┼────┤
# │    │  2 │
# └────┴────┘
#
#  Possible actions: [0, 3]
# Reward Round: 0
# Reward cum: -3120
# ---- 311 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3131
# ---- 312 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3142
# ---- 313 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3153
# ---- 314 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3164
# ---- 315 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3175
# ---- 316 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3186
# ---- 317 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3197
# ---- 318 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3208
# ---- 319 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3219
# ---- 320 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3230
# ---- 321 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3241
# ---- 322 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3252
# ---- 323 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3263
# ---- 324 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3274
# ---- 325 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3285
# ---- 326 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3296
# ---- 327 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3307
# ---- 328 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3318
# ---- 329 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3329
# ---- 330 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3340
# ---- 331 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3351
# ---- 332 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3362
# ---- 333 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -3373
# ---- 334 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3384
# ---- 335 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3395
# ---- 336 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -3406
# ---- 337 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -3417
# ...
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9500
# ---- 891 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9511
# ---- 892 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9522
# ---- 893 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9533
# ---- 894 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9544
# ---- 895 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9555
# ---- 896 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9566
# ---- 897 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9577
# ---- 898 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9588
# ---- 899 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9599
# ---- 900 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9610
# ---- 901 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9621
# ---- 902 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9632
# ---- 903 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9643
# ---- 904 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9654
# ---- 905 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9665
# ---- 906 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9676
# ---- 907 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9687
# ---- 908 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9698
# ---- 909 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9709
# ---- 910 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9720
# ---- 911 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9731
# ---- 912 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9742
# ---- 913 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9753
# ---- 914 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9764
# ---- 915 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9775
# ---- 916 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9786
# ---- 917 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9797
# ---- 918 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9808
# ---- 919 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9819
# ---- 920 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9830
# ---- 921 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -9841
# ---- 922 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9852
# ---- 923 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9863
# ---- 924 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9874
# ---- 925 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9885
# ---- 926 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9896
# ---- 927 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9907
# ---- 928 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9918
# ---- 929 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9929
# ---- 930 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9940
# ---- 931 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9951
# ---- 932 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9962
# ---- 933 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9973
# ---- 934 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -9984
# ---- 935 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -9995
# ---- 936 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10006
# ---- 937 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10017
# ---- 938 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10028
# ---- 939 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10039
# ---- 940 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10050
# ---- 941 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10061
# ---- 942 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10072
# ---- 943 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10083
# ---- 944 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10094
# ---- 945 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10105
# ---- 946 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10116
# ---- 947 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10127
# ---- 948 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10138
# ---- 949 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10149
# ---- 950 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10160
# ---- 951 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10171
# ---- 952 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10182
# ---- 953 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10193
# ---- 954 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10204
# ---- 955 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10215
# ---- 956 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10226
# ---- 957 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10237
# ---- 958 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10248
# ---- 959 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10259
# ---- 960 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10270
# ---- 961 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10281
# ---- 962 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10292
# ---- 963 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10303
# ---- 964 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10314
# ---- 965 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10325
# ---- 966 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10336
# ---- 967 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10347
# ---- 968 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10358
# ---- 969 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10369
# ---- 970 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10380
# ---- 971 ----------
#
# ┌────┬────┐
# │  3 │  2 │
# ├────┼────┤
# │  1 │    │
# └────┴────┘
#
#  Possible actions: [0, 1]
# Reward Round: 0
# Reward cum: -10391
# ---- 972 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10402
# ---- 973 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10413
# ---- 974 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10424
# ---- 975 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10435
# ---- 976 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10446
# ---- 977 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10457
# ---- 978 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10468
# ---- 979 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10479
# ---- 980 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10490
# ---- 981 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10501
# ---- 982 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10512
# ---- 983 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10523
# ---- 984 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10534
# ---- 985 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10545
# ---- 986 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10556
# ---- 987 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10567
# ---- 988 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10578
# ---- 989 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10589
# ---- 990 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10600
# ---- 991 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10611
# ---- 992 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10622
# ---- 993 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10633
# ---- 994 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10644
# ---- 995 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10655
# ---- 996 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10666
# ---- 997 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10677
# ---- 998 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10688
# ---- 999 ----------
#
# ┌────┬────┐
# │    │  3 │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [2, 3]
# Reward Round: 0
# Reward cum: -10699
# ---- 1000 ----------
#
# ┌────┬────┐
# │  3 │    │
# ├────┼────┤
# │  1 │  2 │
# └────┴────┘
#
#  Possible actions: [1, 2]
# Reward Round: 0
# Reward cum: -10710
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# True

# %%
mcLearner.N
# Out:
# {((1, 0, 2, 3), 1): 2,
#  ((0, 1, 2, 3), 2): 2,
#  ((2, 1, 0, 3), 3): 2,
#  ((2, 1, 3, 0), 0): 2,
#  ((2, 0, 3, 1), 1): 2,
#  ((0, 2, 3, 1), 2): 2,
#  ((3, 2, 0, 1), 3): 2,
#  ((3, 2, 1, 0), 0): 2,
#  ((3, 0, 1, 2), 1): 2,
#  ((0, 3, 1, 2), 3): 2,
#  ((1, 3, 0, 2), 0): 2,
#  ((1, 3, 2, 0), 1): 1,
#  ((1, 3, 2, 0), 0): 1}

# %%
mcLearner.Q
# Out:
# {((1, 0, 2, 3), 1): 16.133400003906697,
#  ((0, 1, 2, 3), 2): 16.814888893229664,
#  ((2, 1, 0, 3), 3): 16.46098765914406,
#  ((2, 1, 3, 0), 0): 14.956652954604529,
#  ((2, 0, 3, 1), 1): 16.6185032828939,
#  ((0, 2, 3, 1), 2): 17.35389253654879,
#  ((3, 2, 0, 1), 3): 16.96474083078883,
#  ((3, 2, 1, 0), 0): 15.535885621223981,
#  ((3, 0, 1, 2), 1): 17.245161519790685,
#  ((0, 3, 1, 2), 3): 18.050179466434116,
#  ((1, 3, 0, 2), 0): 16.81751164786687,
#  ((1, 3, 2, 0), 1): 15.066629071261355,
#  ((1, 3, 2, 0), 0): 15.339718189253423}

# %%
mcLearner.played_round
# Out:
# 2000
